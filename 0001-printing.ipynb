# %% [markdown]
# # Python Basics: Using print()
#
# This notebook demonstrates:
# - printing strings
# - printing calculations
# - basic notebook formatting

# %%
# Print a string
print("Hello World")
# Out:
# Hello World

# %%
# Print a calculation
print(4 + 5)
# Out:
# 9
